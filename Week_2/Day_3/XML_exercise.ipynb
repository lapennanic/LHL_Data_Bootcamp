# %% [markdown]
# # XML exercise

# %% [markdown]
# Using data from [**mondial database**](https://drive.google.com/file/d/14lFT4nWHgwN36ij4XZh6OUuup-K9qLgR/view?usp=sharing) find the answers to following questions:
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
import xml.etree.ElementTree as ET

import pandas as pd

tree = ET.parse('data/mondial.xml')

root = tree.getroot()
root
# Out:
# <Element 'mondial' at 0x7f8a9f65c770>

# %%
print(root.tag)
print(root.attrib)
print(len(root))
# Out:
# mondial
# {}
# 3403

# %%
root[0].tag
# Out:
# 'country'

# %%
mortality_dict = {}

countries = []
inf_mort_rates = []

for country in root.findall("country"):
    try:
        inf_mort_rates.append(float(country.find('infant_mortality').text))
        countries.append(str(country.find("name").text))
    except AttributeError:
        continue

country_mortality = {
    "countries" : countries,
    "inf_mort_rates": inf_mort_rates
}

## 1. 10 countries with the lowest infant mortality rates

mort_df["countries"].astype("string")

mort_df = pd.DataFrame(country_mortality)

mort_df.sort_values(by='inf_mort_rates')[0:10]
# Out:
#           countries  inf_mort_rates
# 36           Monaco            1.81
# 90            Japan            2.13
# 109         Bermuda            2.48
# 34           Norway            2.48
# 98        Singapore            2.53
# 35           Sweden            2.60
# 8    Czech Republic            2.63
# 6             Spain            2.70
# 72        Hong Kong            2.73
# 73            Macao            3.13

# %%
country_mortality
# Out:
# {'countries': ['Albania',
#   'Greece',
#   'North Macedonia',
#   'Serbia',
#   'Andorra',
#   'France',
#   'Spain',
#   'Austria',
#   'Czech Republic',
#   'Germany',
#   'Hungary',
#   'Italy',
#   'Liechtenstein',
#   'Slovakia',
#   'Slovenia',
#   'Switzerland',
#   'Belarus',
#   'Latvia',
#   'Lithuania',
#   'Poland',
#   'Ukraine',
#   'Russia',
#   'Belgium',
#   'Luxembourg',
#   'Netherlands',
#   'Bosnia and Herzegovina',
#   'Croatia',
#   'Bulgaria',
#   'Romania',
#   'Turkey',
#   'Denmark',
#   'Estonia',
#   'Faroe Islands',
#   'Finland',
#   'Norway',
#   'Sweden',
#   'Monaco',
#   'Gibraltar',
#   'Guernsey',
#   'Iceland',
#   'Ireland',
#   'San Marino',
#   'Jersey',
#   'Malta',
#   'Isle of Man',
#   'Moldova',
#   'Portugal',
#   'United Kingdom',
#   'Afghanistan',
#   'China',
#   'Iran',
#   'Pakistan',
#   'Tajikistan',
#   'Turkmenistan',
#   'Uzbekistan',
#   'Armenia',
#   'Georgia',
#   'Azerbaijan',
#   'Bahrain',
#   'Bangladesh',
# ...

# %%
# 2. 10 cities with the largest population
cities_pop = {}
cities_pop["city"] = []
cities_pop["population"] = []

for country in root.findall("country"):
    for city in country.findall("city"):
        # find name and add to dict
        city_name = city.find("name").text
        cities_pop["city"].append(city_name)
        for pop in city.findall("population"):
            #find city pop and append to list, temporary list
            temp_pop = []
            temp_pop.append(int(pop.text))
        # take most recent value, for a given country
        cities_pop["population"].append(temp_pop[-1])

# %%
# make a DF
pop_df = pd.DataFrame(cities_pop)

# sort and slice
pop_df.sort_values(by='population', ascending=False)[0:10]
# Out:
#                 city  population
# 155            Seoul     9805506
# 143       Al Qahirah     8471859
# 77           Bangkok     8305218
# 108            Macao     7055071
# 107        Hong Kong     7055071
# 191        Singapore     5076700
# 142  Al Iskandariyah     4123869
# 195       New Taipei     3939305
# 156            Busan     3440484
# 86         Pyongyang     3255288

# %%
# 3. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# make bins
features = {}
features['country'] = []
features['longest river'] = []
features['largest lake'] = []
features['airport elevation'] = []

# for country in root.findall('country'):

rivers = root.find("river")
rivers.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/niclapenna/Documents/GitHub/LHL_Data_Bootcamp/Week_2/Day_3/XML_exercise.ipynb Cell 11' in <cell line: 12>()
#       <a href='vscode-notebook-cell:/Users/niclapenna/Documents/GitHub/LHL_Data_Bootcamp/Week_2/Day_3/XML_exercise.ipynb#ch0000010?line=7'>8</a> features['airport elevation'] = []
#      <a href='vscode-notebook-cell:/Users/niclapenna/Documents/GitHub/LHL_Data_Bootcamp/Week_2/Day_3/XML_exercise.ipynb#ch0000010?line=9'>10</a> # for country in root.findall('country'):
# ---> <a href='vscode-notebook-cell:/Users/niclapenna/Documents/GitHub/LHL_Data_Bootcamp/Week_2/Day_3/XML_exercise.ipynb#ch0000010?line=11'>12</a> rivers = root.find("river")
#      <a href='vscode-notebook-cell:/Users/niclapenna/Documents/GitHub/LHL_Data_Bootcamp/Week_2/Day_3/XML_exercise.ipynb#ch0000010?line=12'>13</a> rivers.value
#
# ...
