# %%
import requests as re
import os

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]

location = "Toronto,Canada"

url = "https://api.foursquare.com/v3/places/search"
headers = {
    "Accept": "application/json",
    "Authorization": api_key
    }

parameters = {
    'near' : location
}


response = re.get(url, headers=headers)
response.json()
# Out:
# {'results': [{'fsq_id': '4c604f7c1e5cd13a6e56a1ed',
#    'categories': [{'id': 16000,
#      'name': 'Landmarks and Outdoors',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 782,
#    'geocodes': {'main': {'latitude': 43.436, 'longitude': -80.41839},
#     'roof': {'latitude': 43.436, 'longitude': -80.41839}},
#    'link': '/v3/places/4c604f7c1e5cd13a6e56a1ed',
#    'location': {'address': '396 Morrison Rd',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '396 Morrison Rd, Kitchener ON N2A 2Z6',
#     'locality': 'Kitchener',
#     'neighborhood': ['Centreville Chicopee'],
#     'postcode': 'N2A 2Z6',
#     'region': 'ON'},
#    'name': 'Chicopee Ski & Summer Resort',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4c9d1fb6d3c2b60c4030bebc',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 803,
#    'geocodes': {'main': {'latitude': 43.442359, 'longitude': -80.414701},
#     'roof': {'latitude': 43.442359, 'longitude': -80.414701}},
#    'link': '/v3/places/4c9d1fb6d3c2b60c4030bebc',
#    'location': {'address': '900 Fairway Cres',
#     'address_extended': '# 2',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '900 Fairway Cres, Kitchener ON N2A 0A1',
#     'locality': 'Kitchener',
#     'neighborhood': ['Lackner Woods'],
#     'postcode': 'N2A 0A1',
#     'region': 'ON'},
#    'name': 'Delicious Pizza',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b9a951ff964a52078c335e3',
#    'categories': [{'id': 17059,
#      'name': 'Butcher',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store / Supermarket',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 1467,
#    'geocodes': {'main': {'latitude': 43.428315, 'longitude': -80.421837},
#     'roof': {'latitude': 43.428315, 'longitude': -80.421837}},
#    'link': '/v3/places/4b9a951ff964a52078c335e3',
#    'location': {'address': '1601 River Rd E',
#     'address_extended': '# 15',
#     'country': 'CA',
#     'cross_street': 'at Morgan Ave.',
#     'formatted_address': '1601 River Rd E (at Morgan Ave.), Kitchener ON N2A 3Y4',
#     'locality': 'Kitchener',
#     'neighborhood': ['Centreville Chicopee'],
#     'postcode': 'N2A 3Y4',
#     'region': 'ON'},
#    'name': "Robert's Boxed Meats",
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4c0aee3732daef3bb3bc4b50',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 1539,
#    'geocodes': {'main': {'latitude': 43.428931, 'longitude': -80.432798},
#     'roof': {'latitude': 43.428931, 'longitude': -80.432798}},
#    'link': '/v3/places/4c0aee3732daef3bb3bc4b50',
#    'location': {'address': '2980 King St E',
#     'country': 'CA',
#     'formatted_address': '2980 King St E, Kitchener ON N2A 1A9',
#     'locality': 'Kitchener',
#     'neighborhood': ['Kitchener'],
#     'postcode': 'N2A 1A9',
#     'region': 'ON'},
#    'name': "Martini's",
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '51072d95e4b0daeeb3bebd21',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13057,
#      'name': 'Gastropub',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 1586,
#    'geocodes': {'main': {'latitude': 43.430104, 'longitude': -80.436271},
#     'roof': {'latitude': 43.430104, 'longitude': -80.436271}},
#    'link': '/v3/places/51072d95e4b0daeeb3bebd21',
#    'location': {'address': '2880 King St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '2880 King St E, Kitchener ON N2A 1A7',
#     'locality': 'Kitchener',
#     'neighborhood': ['Kitchener'],
#     'postcode': 'N2A 1A7',
#     'region': 'ON'},
#    'name': 'The Bent Elbow',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4afcd614f964a520372622e3',
#    'categories': [{'id': 13352,
#      'name': 'Thai Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 1538,
#    'geocodes': {'main': {'latitude': 43.431245, 'longitude': -80.43741},
#     'roof': {'latitude': 43.431245, 'longitude': -80.43741}},
#    'link': '/v3/places/4afcd614f964a520372622e3',
#    'location': {'address': '1500 Weber St E',
#     'country': 'CA',
#     'cross_street': 'King St E',
#     'formatted_address': '1500 Weber St E (King St E), Kitchener ON N2A 2Y5',
#     'locality': 'Kitchener',
#     'neighborhood': ['Centreville Chicopee'],
#     'postcode': 'N2A 2Y5',
#     'region': 'ON'},
#    'name': 'Bangkok Cuisine',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4ba50bc3f964a52027d538e3',
#    'categories': [{'id': 17076,
#      'name': 'Liquor Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 1836,
#    'geocodes': {'main': {'latitude': 43.449498, 'longitude': -80.443948},
#     'roof': {'latitude': 43.449498, 'longitude': -80.443948}},
#    'link': '/v3/places/4ba50bc3f964a52027d538e3',
#    'location': {'address': '1005 Ottawa St N',
#     'address_extended': 'Unit A',
#     'country': 'CA',
#     'cross_street': '1005 Ottawa St. N.',
#     'formatted_address': '1005 Ottawa St N (1005 Ottawa St. N.), Kitchener ON N2A 1H2',
#     'locality': 'Kitchener',
#     'postcode': 'N2A 1H2',
#     'region': 'ON'},
#    'name': 'Lcbo',
#    'related_places': {'parent': {'fsq_id': '4b5f3d0ef964a52057af29e3',
#      'name': 'Stanley Park Mall'}},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4bc1bfc174a9a593de31d2f6',
#    'categories': [{'id': 18075,
#      'name': 'Swimming Pool',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 1759,
#    'geocodes': {'main': {'latitude': 43.456171, 'longitude': -80.434402},
#     'roof': {'latitude': 43.456171, 'longitude': -80.434402}},
#    'link': '/v3/places/4bc1bfc174a9a593de31d2f6',
#    'location': {'address': '600 Heritage Dr',
#     'country': 'CA',
#     'cross_street': 'Ottawa St',
#     'formatted_address': '600 Heritage Dr (Ottawa St), Kitchener ON N2B 3T9',
#     'locality': 'Kitchener',
#     'postcode': 'N2B 3T9',
#     'region': 'ON'},
#    'name': 'Lyle Hallman Pool',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '5d03e7662d2fd9002ca26cb2',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 2290,
#    'geocodes': {'main': {'latitude': 43.423592, 'longitude': -80.43909},
#     'roof': {'latitude': 43.423592, 'longitude': -80.43909}},
#    'link': '/v3/places/5d03e7662d2fd9002ca26cb2',
#    'location': {'address': '2960 Kingsway Dr',
#     'address_extended': '# 15A',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '2960 Kingsway Dr, Kitchener ON N2C 1X1',
#     'locality': 'Kitchener',
#     'neighborhood': ['Kitchener'],
#     'postcode': 'N2C 1X1',
#     'region': 'ON'},
#    'name': "Jack Astor's",
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '5841cca1876ade32f721d8f2',
#    'categories': [{'id': 17057,
#      'name': 'Food and Beverage Retail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 2677,
#    'geocodes': {'main': {'latitude': 43.421601, 'longitude': -80.444221},
#     'roof': {'latitude': 43.421601, 'longitude': -80.444221}},
#    'link': '/v3/places/5841cca1876ade32f721d8f2',
#    'location': {'address': '310 Fairway Rd S',
#     'country': 'CA',
#     'cross_street': 'at Wilson AVE',
#     'formatted_address': '310 Fairway Rd S (at Wilson AVE), Kitchener ON N2C 1X3',
#     'locality': 'Kitchener',
#     'neighborhood': ['Kitchener'],
#     'postcode': 'N2C 1X3',
#     'region': 'ON'},
#    'name': 'Firehouse Subs',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.44129943847656,
#      'longitude': -80.42459869384766},
#     'radius': 5194}}}}

# %%
print(os.environ["FOURSQUARE_API_KEY"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/niclapenna/lighthouse_working/Week_1/Day_3/python_apis.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/niclapenna/lighthouse_working/Week_1/Day_3/python_apis.ipynb#ch0000002?line=0'>1</a> print(os.environ["FOURSQUARE_API_KEY"])
#
# File ~/opt/anaconda3/envs/lhl_env/lib/python3.10/os.py:679, in _Environ.__getitem__(self, key)
#     <a href='file:///Users/niclapenna/opt/anaconda3/envs/lhl_env/lib/python3.10/os.py?line=675'>676</a>     value = self._data[self.encodekey(key)]
#     <a href='file:///Users/niclapenna/opt/anaconda3/envs/lhl_env/lib/python3.10/os.py?line=676'>677</a> except KeyError:
#     <a href='file:///Users/niclapenna/opt/anaconda3/envs/lhl_env/lib/python3.10/os.py?line=677'>678</a>     # raise KeyError with the original key value
# --> <a href='file:///Users/niclapenna/opt/anaconda3/envs/lhl_env/lib/python3.10/os.py?line=678'>679</a>     raise KeyError(key) from None
#     <a href='file:///Users/niclapenna/opt/anaconda3/envs/lhl_env/lib/python3.10/os.py?line=679'>680</a> return self.decodevalue(value)
#
# KeyError: 'FOURSQUARE_API_KEY'
