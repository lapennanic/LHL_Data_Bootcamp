# %% [markdown]
# ## Advanced tuning of parameters
#
# In this tutorial, we will apply the skills from previous tutorials and build a classifier using the `Pipelines` and `FeatureUnion` functions from sklearn.

# %%
# IMPORT PACKAGES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # For plotting data
import seaborn as sns # For plotting data

from sklearn.model_selection import train_test_split # For train/test splits
from sklearn.neighbors import KNeighborsClassifier # The k-nearest neighbor classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold # Feature selector
from sklearn.pipeline import Pipeline, FeatureUnion # For setting up pipeline
from sklearn.svm import SVC

# Various pre-processing steps
from sklearn.preprocessing import Normalizer, StandardScaler, MinMaxScaler, PowerTransformer, MaxAbsScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV # For optimization
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# ### Data
#
# We will be building a binary classifier that predicts wheter a person has diabetes or not, using information on the patient's health.
#
# The data can be found [here](https://drive.google.com/file/d/1TvCKlmH3Z32XAKk-VUcZyYu95Ccyw3PO/view?usp=sharing).

# %%
col_names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %%
data = pd.read_csv('data/pima-indians-diabetes.csv', delimiter=';')

# %%
y = data['class']
X = data.drop('class', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25)

# %% [markdown]
# ### Task
#
# Build classifier which predicts the target variable `class` using rest of the attributes. The model should be fitted using pipeline that contains:
# - PCA method
# - SelectKBest method
# - FeatureUnion
# - Random Forest
#
# Choose the best set of parameters using `Pipeline` and grid_search.
#
# > #### Note
# > **In this exercise, we are focusing on the implementation of pipeline. Since we have only 9 columns in our dataset the PCA is probably not the best technique to use during the data preparation from a methodology point of view.**

# %%
pca = PCA(n_components=2)

selection = SelectKBest(k=3)

# %%
combined_features = FeatureUnion([('pca',pca),('univ_select', selection)])

# %%
rfc = RandomForestClassifier()

# %%
pipeline = Pipeline([('features', combined_features), ('rfc', rfc)])

# %%
param_grid = {
    "features__pca__n_components": [1,2,3],
    "features__univ_select__k": [1,2,3],
    "rfc__n_estimators": [25,100,200]
}

# create a Grid Search object
grid_search = GridSearchCV(pipeline, param_grid, verbose=10,refit=True)

# %%
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25
# [CV 1/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25;, score=0.688 total time=   0.1s
# [CV 2/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25
# [CV 2/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25;, score=0.656 total time=   0.1s
# [CV 3/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25
# [CV 3/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25;, score=0.727 total time=   0.1s
# [CV 4/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25
# [CV 4/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25;, score=0.732 total time=   0.0s
# [CV 5/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25
# [CV 5/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=25;, score=0.680 total time=   0.1s
# [CV 1/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100
# [CV 1/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100;, score=0.695 total time=   0.2s
# [CV 2/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100
# [CV 2/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100;, score=0.656 total time=   0.2s
# [CV 3/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100
# [CV 3/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100;, score=0.701 total time=   0.2s
# [CV 4/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100
# [CV 4/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100;, score=0.706 total time=   0.1s
# [CV 5/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100
# [CV 5/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=100;, score=0.667 total time=   0.2s
# [CV 1/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200
# [CV 1/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200;, score=0.701 total time=   0.3s
# [CV 2/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200
# [CV 2/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200;, score=0.636 total time=   0.3s
# [CV 3/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200
# [CV 3/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200;, score=0.714 total time=   0.3s
# [CV 4/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200
# [CV 4/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200;, score=0.699 total time=   0.3s
# [CV 5/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200
# [CV 5/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, rfc__n_estimators=200;, score=0.680 total time=   0.4s
# [CV 1/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25
# [CV 1/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25;, score=0.753 total time=   0.1s
# [CV 2/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25
# [CV 2/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25;, score=0.688 total time=   0.0s
# [CV 3/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25
# [CV 3/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25;, score=0.721 total time=   0.0s
# [CV 4/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25
# [CV 4/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25;, score=0.784 total time=   0.0s
# [CV 5/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25
# [CV 5/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=25;, score=0.699 total time=   0.1s
# [CV 1/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100
# [CV 1/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100;, score=0.708 total time=   0.1s
# [CV 2/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100
# [CV 2/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100;, score=0.701 total time=   0.2s
# [CV 3/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100
# [CV 3/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100;, score=0.734 total time=   0.1s
# [CV 4/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100
# [CV 4/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100;, score=0.771 total time=   0.2s
# [CV 5/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100
# [CV 5/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=100;, score=0.686 total time=   0.2s
# [CV 1/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200
# [CV 1/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200;, score=0.734 total time=   0.3s
# [CV 2/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200
# [CV 2/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200;, score=0.701 total time=   0.3s
# [CV 3/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200
# [CV 3/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200;, score=0.747 total time=   0.3s
# [CV 4/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200
# [CV 4/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200;, score=0.778 total time=   0.3s
# [CV 5/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200
# [CV 5/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, rfc__n_estimators=200;, score=0.673 total time=   0.3s
# [CV 1/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25
# [CV 1/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25;, score=0.727 total time=   0.0s
# [CV 2/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25
# [CV 2/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25;, score=0.734 total time=   0.1s
# [CV 3/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25
# [CV 3/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25;, score=0.753 total time=   0.0s
# [CV 4/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25
# [CV 4/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25;, score=0.804 total time=   0.1s
# [CV 5/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25
# [CV 5/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=25;, score=0.680 total time=   0.1s
# [CV 1/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100
# [CV 1/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100;, score=0.760 total time=   0.2s
# [CV 2/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100
# [CV 2/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100;, score=0.708 total time=   0.2s
# [CV 3/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100
# [CV 3/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100;, score=0.766 total time=   0.2s
# [CV 4/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100
# [CV 4/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100;, score=0.778 total time=   0.2s
# [CV 5/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100
# [CV 5/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=100;, score=0.693 total time=   0.2s
# [CV 1/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200
# [CV 1/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200;, score=0.760 total time=   0.3s
# [CV 2/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200
# [CV 2/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200;, score=0.721 total time=   0.3s
# [CV 3/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200
# [CV 3/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200;, score=0.753 total time=   0.3s
# [CV 4/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200
# [CV 4/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200;, score=0.810 total time=   0.4s
# [CV 5/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200
# [CV 5/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, rfc__n_estimators=200;, score=0.673 total time=   0.4s
# [CV 1/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25
# [CV 1/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25;, score=0.727 total time=   0.1s
# [CV 2/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25
# [CV 2/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25;, score=0.656 total time=   0.1s
# [CV 3/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25
# [CV 3/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25;, score=0.734 total time=   0.1s
# [CV 4/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25
# [CV 4/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25;, score=0.771 total time=   0.1s
# [CV 5/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25
# [CV 5/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=25;, score=0.667 total time=   0.1s
# [CV 1/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100
# [CV 1/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100;, score=0.721 total time=   0.3s
# [CV 2/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100
# [CV 2/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100;, score=0.669 total time=   0.2s
# [CV 3/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100
# [CV 3/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100;, score=0.695 total time=   0.2s
# [CV 4/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100
# [CV 4/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100;, score=0.752 total time=   0.2s
# [CV 5/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100
# [CV 5/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=100;, score=0.699 total time=   0.3s
# [CV 1/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200
# [CV 1/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200;, score=0.734 total time=   0.4s
# [CV 2/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200
# [CV 2/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200;, score=0.662 total time=   0.3s
# [CV 3/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200
# [CV 3/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200;, score=0.708 total time=   0.4s
# [CV 4/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200
# [CV 4/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200;, score=0.725 total time=   0.4s
# [CV 5/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200
# [CV 5/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, rfc__n_estimators=200;, score=0.693 total time=   0.4s
# [CV 1/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25
# [CV 1/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25;, score=0.727 total time=   0.1s
# [CV 2/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25
# [CV 2/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25;, score=0.701 total time=   0.1s
# [CV 3/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25
# [CV 3/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25;, score=0.747 total time=   0.1s
# [CV 4/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25
# [CV 4/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25;, score=0.752 total time=   0.1s
# [CV 5/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25
# [CV 5/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=25;, score=0.706 total time=   0.1s
# [CV 1/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100
# [CV 1/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100;, score=0.721 total time=   0.2s
# [CV 2/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100
# [CV 2/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100;, score=0.734 total time=   0.2s
# [CV 3/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100
# [CV 3/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100;, score=0.753 total time=   0.2s
# [CV 4/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100
# [CV 4/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100;, score=0.752 total time=   0.2s
# [CV 5/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100
# [CV 5/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=100;, score=0.699 total time=   0.2s
# [CV 1/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200
# [CV 1/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200;, score=0.727 total time=   0.4s
# [CV 2/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200
# [CV 2/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200;, score=0.734 total time=   0.4s
# [CV 3/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200
# [CV 3/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200;, score=0.740 total time=   0.4s
# [CV 4/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200
# [CV 4/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200;, score=0.771 total time=   0.4s
# [CV 5/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200
# [CV 5/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, rfc__n_estimators=200;, score=0.706 total time=   0.4s
# [CV 1/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25
# [CV 1/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25;, score=0.786 total time=   0.1s
# [CV 2/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25
# [CV 2/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25;, score=0.708 total time=   0.0s
# [CV 3/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25
# [CV 3/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25;, score=0.753 total time=   0.0s
# [CV 4/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25
# [CV 4/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25;, score=0.810 total time=   0.1s
# [CV 5/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25
# [CV 5/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=25;, score=0.693 total time=   0.1s
# [CV 1/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100
# [CV 1/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100;, score=0.766 total time=   0.2s
# [CV 2/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100
# [CV 2/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100;, score=0.701 total time=   0.2s
# [CV 3/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100
# [CV 3/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100;, score=0.753 total time=   0.2s
# [CV 4/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100
# [CV 4/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100;, score=0.824 total time=   0.2s
# [CV 5/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100
# [CV 5/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=100;, score=0.719 total time=   0.2s
# [CV 1/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200
# [CV 1/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200;, score=0.773 total time=   0.4s
# [CV 2/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200
# [CV 2/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200;, score=0.688 total time=   0.5s
# [CV 3/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200
# [CV 3/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200;, score=0.773 total time=   0.4s
# [CV 4/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200
# [CV 4/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200;, score=0.824 total time=   0.4s
# [CV 5/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200
# [CV 5/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, rfc__n_estimators=200;, score=0.712 total time=   0.4s
# [CV 1/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25
# [CV 1/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25;, score=0.721 total time=   0.1s
# [CV 2/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25
# [CV 2/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25;, score=0.610 total time=   0.1s
# [CV 3/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25
# [CV 3/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25;, score=0.675 total time=   0.1s
# [CV 4/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25
# [CV 4/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25;, score=0.739 total time=   0.1s
# [CV 5/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25
# [CV 5/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=25;, score=0.719 total time=   0.1s
# [CV 1/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100
# [CV 1/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100;, score=0.714 total time=   0.3s
# [CV 2/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100
# [CV 2/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100;, score=0.643 total time=   0.2s
# [CV 3/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100
# [CV 3/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100;, score=0.714 total time=   0.2s
# [CV 4/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100
# [CV 4/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100;, score=0.732 total time=   0.2s
# [CV 5/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100
# [CV 5/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=100;, score=0.712 total time=   0.2s
# [CV 1/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200
# [CV 1/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200;, score=0.708 total time=   0.4s
# [CV 2/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200
# [CV 2/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200;, score=0.656 total time=   0.5s
# [CV 3/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200
# [CV 3/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200;, score=0.708 total time=   0.5s
# [CV 4/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200
# [CV 4/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200;, score=0.739 total time=   0.5s
# [CV 5/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200
# [CV 5/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, rfc__n_estimators=200;, score=0.706 total time=   0.4s
# [CV 1/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25
# [CV 1/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25;, score=0.779 total time=   0.1s
# [CV 2/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25
# [CV 2/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25;, score=0.701 total time=   0.1s
# [CV 3/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25
# [CV 3/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25;, score=0.727 total time=   0.1s
# [CV 4/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25
# [CV 4/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25;, score=0.752 total time=   0.1s
# [CV 5/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25
# [CV 5/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=25;, score=0.725 total time=   0.1s
# [CV 1/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100
# [CV 1/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100;, score=0.760 total time=   0.2s
# [CV 2/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100
# [CV 2/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100;, score=0.695 total time=   0.2s
# [CV 3/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100
# [CV 3/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100;, score=0.734 total time=   0.2s
# [CV 4/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100
# [CV 4/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100;, score=0.752 total time=   0.2s
# [CV 5/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100
# [CV 5/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=100;, score=0.739 total time=   0.2s
# [CV 1/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200
# [CV 1/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200;, score=0.773 total time=   0.5s
# [CV 2/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200
# [CV 2/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200;, score=0.688 total time=   0.4s
# [CV 3/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200
# [CV 3/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200;, score=0.721 total time=   0.4s
# [CV 4/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200
# [CV 4/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200;, score=0.791 total time=   0.4s
# [CV 5/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200
# [CV 5/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, rfc__n_estimators=200;, score=0.725 total time=   0.4s
# [CV 1/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25
# [CV 1/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25;, score=0.747 total time=   0.1s
# [CV 2/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25
# [CV 2/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25;, score=0.701 total time=   0.1s
# [CV 3/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25
# [CV 3/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25;, score=0.740 total time=   0.1s
# [CV 4/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25
# [CV 4/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25;, score=0.830 total time=   0.1s
# [CV 5/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25
# [CV 5/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=25;, score=0.745 total time=   0.1s
# [CV 1/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100
# [CV 1/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100;, score=0.779 total time=   0.2s
# [CV 2/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100
# [CV 2/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100;, score=0.695 total time=   0.2s
# [CV 3/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100
# [CV 3/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100;, score=0.753 total time=   0.2s
# [CV 4/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100
# [CV 4/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100;, score=0.804 total time=   0.2s
# [CV 5/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100
# [CV 5/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=100;, score=0.719 total time=   0.2s
# [CV 1/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200
# [CV 1/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200;, score=0.766 total time=   0.4s
# [CV 2/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200
# [CV 2/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200;, score=0.675 total time=   0.4s
# [CV 3/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200
# [CV 3/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200;, score=0.779 total time=   0.4s
# [CV 4/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200
# [CV 4/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200;, score=0.817 total time=   0.4s
# [CV 5/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200
# [CV 5/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, rfc__n_estimators=200;, score=0.725 total time=   0.4s
# GridSearchCV(estimator=Pipeline(steps=[('features',
#                                         FeatureUnion(transformer_list=[('pca',
#                                                                         PCA(n_components=2)),
#                                                                        ('univ_select',
#                                                                         SelectKBest(k=3))])),
#                                        ('rfc', RandomForestClassifier())]),
#              param_grid={'features__pca__n_components': [1, 2, 3],
#                          'features__univ_select__k': [1, 2, 3],
#                          'rfc__n_estimators': [25, 100, 200]},
#              verbose=10)
