# %% [markdown]
# ### Stationarity Exercise

# %%
# import matplotlib
import matplotlib.pyplot as plt

# import random
import random
import numpy as np

# set a random seed
random.seed(5)

# %% [markdown]
# * generate a NON stationary time-series

# %%
non_stationary = []
for i in range(0,100):
    non_stationary.append(random.random()+(i*.03))

# %%
plt.plot(non_stationary)
plt.title('Non-Stationary Time Series')
plt.show()

# %% [markdown]
# * plot the NON stationary series generated above

# %% [markdown]
# * generate a stationary time-series

# %%
n = 100
x = np.arange(n)
stationary = np.random.uniform(-1,1,[n])

# %% [markdown]
# * plot the stationary series generated above

# %%
plt.plot(x,stationary)
plt.show()

# %% [markdown]
# * Create a function `'ADF_Stationarity_Test'` with the input parameters `timeseries` and `significance_level` which:
#     * prints the adfuller test results
#     * prints the conclusion stating whether timeseries is stationary based on the siginificance level (input parameter of function)

# %%
import statsmodels
from statsmodels.tsa.stattools import adfuller
import pandas as pd

def ADF_Stationarity_Test(timeseries, significance_level):
    result = adfuller(timeseries)
    print(result)
    if result[1] < significance_level:
        print(f'The time series is stationary with a p-value of {result[1]}')
    else:
        print(f'The time series is not stationary with a p-value of {result[1]}')

# %% [markdown]
# * Apply the function `'ADF_Stationarity_Test'` to find out whether the timeseries generated above are stationary.

# %%
ADF_Stationarity_Test(stationary, 0.5)
# Out:
# (-8.97650062493839, 7.507174032754622e-15, 0, 99, {'1%': -3.498198082189098, '5%': -2.891208211860468, '10%': -2.5825959973472097}, 147.60658959067626)
# The time series is stationary with a p-value of 7.507174032754622e-15

# %%
ADF_Stationarity_Test(non_stationary, 0.5)
# Out:
# (-0.5934829303875584, 0.872447828119145, 6, 93, {'1%': -3.502704609582561, '5%': -2.8931578098779522, '10%': -2.583636712914788}, 49.1760413084541)
# The time series is not stationary with a p-value of 0.872447828119145

# %% [markdown]
# * Apply a suitable transformation to make the NON stationary time series stationary.

# %%
non_stationary = np.log(non_stationary)

# %% [markdown]
# * plot the transformed time series

# %%
plt.plot(x,non_stationary)
plt.show()

# %% [markdown]
# * Apply the function `'ADF_Stationarity_Test'` to find out whether the transformed timeseries is stationary.

# %%
ADF_Stationarity_Test(non_stationary, 0.5)
# Out:
# (-3.377464085472026, 0.011751533606131497, 8, 91, {'1%': -3.50434289821397, '5%': -2.8938659630479413, '10%': -2.5840147047458037}, -52.38389721785944)
# The time series is stationary with a p-value of 0.011751533606131497
