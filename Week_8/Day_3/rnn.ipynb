# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import TextVectorization
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, LSTM, Reshape

import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data/colors.csv")
names = data["name"]
data.head()
# Out:
#                           name  red  green  blue
# 0           18th Century Green  165    147    68
# 1               1975 Earth Red  123     70    59
# 2           1989 Miami Hotline  221     51   102
# 3  20000 Leagues Under the Sea   25     25   112
# 4               3AM in Shibuya   34     85   119

# %%
h = sorted(names.str.len().values)
import numpy as np
import scipy.stats as stats
import pylab as plt

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed
plt.plot(h,fit,'-o')
plt.hist(h)      #use this to draw histogram of your data
plt.xlabel('Chars')
plt.ylabel('Probability density')
plt.show()

# %%
maxlen = 25
t = TextVectorization(char_level=True)
t.fit_on_texts(names)
tokenized = t.texts_to_sequences(names)
padded_names = preprocessing.sequence.pad_sequences(tokenized, maxlen=maxlen)
print(padded_names.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/q4/hl7yv5yn6g10s9npc_7kk08h0000gn/T/ipykernel_20754/1565720243.py in <module>
#       1 maxlen = 25
# ----> 2 t = TextVectorization(char_level=True)
#       3 t.fit_on_texts(names)
#       4 tokenized = t.texts_to_sequences(names)
#       5 padded_names = preprocessing.sequence.pad_sequences(tokenized, maxlen=maxlen)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/preprocessing/text_vectorization.py in __init__(self, max_tokens, standardize, split, ngrams, output_mode, output_sequence_length, pad_to_max_tokens, vocabulary, idf_weights, sparse, ragged, **kwargs)
#     347     kwargs.pop("vocabulary_size", None)
#     348
# --> 349     super().__init__(**kwargs)
#     350     base_preprocessing_layer.keras_kpl_gauge.get_cell("TextVectorization").set(
#     351         True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_preprocessing_layer.py in __init__(self, **kwargs)
#      51
#      52   def __init__(self, **kwargs):
# ---> 53     super(PreprocessingLayer, self).__init__(**kwargs)
#      54     self._is_compiled = False
#      55     self._is_adapted = False
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     585     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586     try:
# --> 587       result = method(self, *args, **kwargs)
#     588     finally:
#     589       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     330     }
#     331     # Validate optional keyword arguments.
# --> 332     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     333
#     334     # Mutable properties
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    1172   for kwarg in kwargs:
#    1173     if kwarg not in allowed_kwargs:
# -> 1174       raise TypeError(error_message, kwarg)
#    1175
#    1176
#
# TypeError: ('Keyword argument not understood:', 'char_level')
